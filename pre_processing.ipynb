# %%
import pandas as pd


df = pd.read_csv('emoji_df.csv')

# %%
df
# Out:
#         emoji                             name              group  \
# 0           😀                    grinning face  Smileys & Emotion
# 1           😃      grinning face with big eyes  Smileys & Emotion
# 2           😄  grinning face with smiling eyes  Smileys & Emotion
# 3           😁   beaming face with smiling eyes  Smileys & Emotion
# 4           😆          grinning squinting face  Smileys & Emotion
# ...       ...                              ...                ...
# 4154       🇿🇲                     flag: Zambia              Flags
# 4155       🇿🇼                   flag: Zimbabwe              Flags
# 4156  🏴󠁧󠁢󠁥󠁮󠁧󠁿                    flag: England              Flags
# 4157  🏴󠁧󠁢󠁳󠁣󠁴󠁿                   flag: Scotland              Flags
# 4158  🏴󠁧󠁢󠁷󠁬󠁳󠁿                      flag: Wales              Flags
#
#              sub_group                                 codepoints
# 0         face-smiling                                      1F600
# ...

# %%
# df should only have emoji and name columns
df = df[['emoji', 'name']]

# %%
df.head(5)
# Out:
#   emoji                             name
# 0     😀                    grinning face
# 1     😃      grinning face with big eyes
# 2     😄  grinning face with smiling eyes
# 3     😁   beaming face with smiling eyes
# 4     😆          grinning squinting face

# %%
df.to_csv('emoji_df.csv', index=False)
